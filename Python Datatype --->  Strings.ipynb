# %% [raw]
#   ############    ###########  Python Datatype --> Strings  #########   ##########   ##########   ########

# %%
                 ###   Strings  ### 

 =>  In Python, Strings are arrays of bytes representing Unicode characters.
      
 =>  Python does not have a character data type, a single character is simply a string with a length of 1. 

 =>  Square brackets can be used to access elements of the string.

 =>  Strings in Python can be created using single quotes or double quotes or even triple quotes.

# %%
#  Python program to create strings

string1 = 'Hello'
string2 = "Hello world"
string3 = ''' Hello world!                                  # This is a multi-line string.
                  This is a Triple-quoted string. '''


string4 = '10'              # This is a string in integer.
string5 = '1.05'            # This is a string in float

# %%
 ##########  ############   Concatenation of Strings    ##########  ############   #############   ###########
    
 =>  String Concatenation is the technique of combining two strings and can be done in many ways.
       
      * Using + operator  * Using join() method  * Using % operator * Using format() function
 

 >>> var1 = 'Hello'; var2 = 'World'

_______________________________________________________________________________________________________________________    


*  Using '+' Operator

   =>  It’s very easy to use + operator for string concatenation. 
          This operator can be used to add multiple strings together. 
               However, the arguments must be a string.

     Note: Strings are immutable, therefore, whenever it is concatenated, it is assigned to a new variable.
        
 
 >>> concatenate_string = var1 + var2 
    
    #  This above code joins 2 strings and store the new string in a new variable.
_____________________________________________________________________________________________________________________    
    

*  Using join() Method
 
   =>>  The join() method is a string method and returns a string in which the elements of sequence 
              have been joined by str separator.
    
 
 >>> print("".join([var1, var2]))      ---->>    var1var2       #  This joins 2 string without any space.
 >>> print(" ".join([var1, var2]))     ---->>   var1  var2      #  This joins 2 string wityh given space.
    
 
 =>  The variable var1 stores the string “Hello” and variable var2 stores the string “World”. 
      
 =>  The join() method combines the string that is stored in the var1 and var2.

 =>  The join method accepts only the list as it’s argument and list size can be anything. 

 =>  We can store the combined string in another variable var3 which is separated by space.

_______________________________________________________________________________________________________________________
    

*  Using % Operator

   =>>  We can use % operator for string formatting, it can also be used for string concatenation. 
          It’s useful when we want to concatenate strings and perform simple formatting.
 
 
 >>> print("% s % s" % (var1, var2))  -->>  var1 var2

 
 =>  The % Operator combine the string that is stored in the var1 and var2. 
    
 =>  The %s denotes string data type. 
   
 =>  The value in both the variable is passed to the string %s and becomes “Hello World”.

________________________________________________________________________________________________________________________      
        

*  Using format() function

   =>  str.format() is one of the string formatting methods in Python, which allows multiple substitutions 
           and value formatting. 
        
   =>  This method lets us concatenate elements within a string through positional formatting.
            
 
 >>> print("{} {}".format(var1, var2))    ---->>>   Hello World


 =>  The format() function combines the string that is stored in the var1 and var2 and stores 
         in another variable var3. 
        
 =>  The curly braces {} are used to set the position of strings. 

 =>  The first variable stores in the first curly braces and second variable stores in the second curly braces.
       Finally it prints the value “Hello World”.

# %%
# Python program to demonstrate 
# string concatenation 


var1 = "Hello"
var2 = "World"

# format function is used here to 
# combine the string 
print("{} {}".format(var1, var2)) 

# store the result in another variable 
var3 = "{} {}".format(var1, var2) 

print(var3)
# Out:
# Hello World
# Hello World

# %%
 #          #        Indexing in a string         #             #
    
 =>  In Python, Individual characters of a String can be accessed by using the method of Indexing. 
 
 =>  Accessing an Index out of the range will cause an IndexError.

 =>  Only Integers are allowed to be passed as an index, float or other types will cause a TypeError.

# %% [markdown]
# <img src="images/strings.jpg">

# %%
#      #         #         Indexing of strings          #              #
string = 'Geeksforgeeks'

print(string[0])
print(string[1])
print(string[-1])

# %%
               ####  Slicing of Strings   ####
    
 =>  Slicing of Strings is a used to slice and print a specific range of items from the original string 
       in a specific manner.
    
 =>  Slicing is performed by using -->>>  [:] .

 
 >>> string[:]      --->>     #  Slices and Prints all items of strinng
 
 >>> string[:j]      --->>    #  Slices and Prints from Beginning to 'j' th index; 
                              #       by excluding the item at 'j' th index
    
 >>> string[i:]      --->>    #  Slices and Prints from 'i' th index to the end of string;
                              #       by including the character at 'i' th index
    
 >>> string[::]      --->>    #  Slices and Prints the whole String

 >>> string[::k]    --->>     #  Slices and Prints the String's item at a jump of 'k'
    
 >>> string[::-k]  --->>     #  Slices and Prints the string's item at a jump of 'k' in Reversed direction.

# %%
#           #####  Escape sequencing in Python   #####
    
# Python Program for Escape Sequencing of String 

# Initial String 
String1 = '''I'm a "Geek"'''
print("Initial String with use of Triple Quotes: ") 
print(String1) 

# Escaping Single Quote 
String1 = 'I\'m a "Geek"'
print("\nEscaping Single Quote: ") 
print(String1) 

# Escaping Doule Quotes 
String1 = "I'm a \"Geek\""
print("\nEscaping Double Quotes: ") 
print(String1) 

# Printing Paths with the 
# use of Escape Sequences 
String1 = "C:\\Python\\Geeks\\"
print("\nEscaping Backslashes: ") 
print(String1) 
  
#  =>  To ignore the escape sequences in a String, r or R is used before the starting of Strings.

# Printing Geeks in HEX 
String1 = "This is \x47\x65\x65\x6b\x73 in \x48\x45\x58"
print("\nPrinting in HEX with the use of Escape Sequences: ") 
print(String1) 

# Using raw String to 
# ignore Escape Sequences 
String1 = r"This is \x47\x65\x65\x6b\x73 in \x48\x45\x58"
print("\nPrinting Raw String in HEX Format: ") 
print(String1)

# %%
              #######     Formatting Of Strings      ########
    
 =>  Strings in Python can be formatted with the use of format() method which is very versatile 
         and powerful tool for formatting of Strings.
 
 =>  Format method in String contains curly braces {} as placeholders which can hold arguments
         according to position or keyword to specify the order.

# %%
# Python Program for Formatting of Strings 

# Default order 
String1 = "{} {} {}".format('Geeks', 'For', 'Life') 
print("Print String in default order: ") 
print(String1) 

# Positional Formatting 
String1 = "{1} {0} {2}".format('Geeks', 'For', 'Life') 
print("\nPrint String in Positional order: ") 
print(String1) 

# Keyword Formatting 
String1 = "{l} {f} {g}".format(g = 'Geeks', f = 'For', l = 'Life') 
print("\nPrint String in order of Keywords: ") 
print(String1)

# %%
#   A string can be left() or center(^) justified with the use of format specifiers, separated by colon(:).

# String alignment 
String1 = "|{:<10}|{:^10}|{:>10}|".format('Geeks','for','Geeks') 
print("\nLeft, center and right alignment with Formatting: ") 
print(String1) 

# To demonstrate aligning of spaces 
String1 = "\n{0:^16} was founded in {1:<4}!".format("GeeksforGeeks", 2009) 
print(String1)

# %%
#          #######      #######     String - Methods     ######      ###########

# %% [markdown]
# <img src="images/string-methods2.png">

# %% [markdown]
# <img src="images/string-methods3.png">

# %%
   #######      ########       Some String Constants       ########     ########

# %% [markdown]
# <img src="images/string-constants2.png">

# %% [markdown]
# <img src="images/string-constants3.png">

# %%
    #######   ##########   Deleting/Updating from a String   #########    ##########
    
 =>  In Python, Updation or deletion of characters from a String is not allowed. 

 =>  This will cause an error because item assignment or item deletion from a String is not supported. 
     
 =>  Although deletion of entire String is possible with the use of a built-in del keyword. 
      
 =>  This is because Strings are immutable, hence elements of a String cannot be changed once it has been assigned. 
       Only new strings can be reassigned to the same name.
    
#  Python Program to display the updation of items of string
 >>>  string[i] = 'v'     --->>>    This gives a TypeError.      # Updating an item
 >>>  del string[i]       --->>>    This raises a TypeError.     # Deleting an item

# %%
 ##########   #######  Re-assignment of string & Deletion  #############    ##########

 =>  We can assign a new string with the same name. This assignment can be said as String Updation.

 =>  'del' keyword is used to delete the whole string.
     
 =>  Printing a deleted string will raise a 'NameError'.

# %%
  #######   ########   ########  Some Built-in methods for Strings   ########   ##########   ############ ####

 
 >>> string.capitalize() --> This return a capitalized version of string.

 
 >>> string.casefold() -->  This return a version of the string witha lowercase letters.

 
 >>> string.count(substring_characters) --> This return the number of occurrences of substring in
                                                string.
    
 
 >>> string.center(width, fill_char) 
    
      => This return a centered string of length equal to 'width'.
      => fill_char specifies the space to pad the string. Default is space.
 
________________________________________________________________________________________________________________________
 
 
 >>> string.endswith(suffix_characters) -> bool
  
      => This return True if string ends with the specified suffix, False otherwise.
      => (start, end) are optional values.
      => Checking starts with 'start' and 'end' position.
      => suffix can also be a tuple of strings to try.
        
 
 >>> string.expandtabs(tabsize=8)

      => This return a copy where all tab characters are expanded using spaces.

 
 >>> string.find(substring_characters) 
      => Return the lowest index in string where substring is found,
               such that substring is contained within S[start:end]. 
            

 >>> string.format(*args, **kwargs)
      => Return a formatted version of S, using substitutions from args and kwargs.
    
 
 >>> string.format_map(mapping)
      => Return a formatted version of S, using substitutions from mapping.
    
 
 >>> string.index(substring, start, end)
      => Return the lowest index in S where substring sub is found, such that sub is contained within S[start:end]. 
 
__________________________________________________________________________________________________________________________
 

 >>> string.isalnum()  --> Return True if the string is an alpha-numeric string, False otherwise.

 >>> string.alpha() --> Return True if the string is an alphabetic string, False otherwise.
    
 >>> string.isascii() --> Return True if all characters in the string are ASCII, False otherwise.

 >>> string.isdecimal() -->  Return True if the string is a decimal string, False otherwise.
    
 >>> string.isdigit() -->  Return True if the string is a digit string, False otherwise.
 
 >>> string.identifier() -->  Return True if the string is a valid Python identifier, False otherwise.

 >>> string.islower() -->  Return True if the string is a lowercase string, False otherwise.
    
 >>> string.isnumeric() -->  Return True if the string is a numeric string, False otherwise.

 >>> string.isprintable() -->  Return True if the string is printable, False otherwise.

 >>> string.isspace() -->  Return True if the string is a whitespace string, False otherwise.

 >>> string.istitle() -->  Return True if the string is a title-cased string, False otherwise.
    
 >>> string.isupper() -->  Return True if the string is an uppercase string, False otherwise.

 
_____________________________________________________________________________________________________________________   
    
 
 >>> string.join(iterable) --> This is used to concatenate any number of strings.
    
 
 >>> string.lower() -->  This return a copy of the string with letters in lowercase.

 
 >>> string.ljust(width, fill_char) --> This return a left-justified string of length equal to width.
    
 
 >>> string.maketrans(x, y=None, z=None) --> This return a Translation - Table using for maketrans() .

 
 
 >>> string.partition(sep) -->  Partition the string into three parts using the given separator.
    
 
 >>> string.rindex(substring, start, end) -->  This return the highest index in string where substring sub is found.

 
 >>> string.rfind(substring, start, end) -->  This return the highest index in string where substring sub is found.


 >>> string.replce (old, new) 

      =>  This return a copy with all occurrences of substring old replaced by new.
 
__________________________________________________________________________________________________________________________
 
 
 >>> string.rjust(width, fill-char)
      
      => This return a right-justified string of length equal to width.

 
 >>> string.rpartition(sep) -->  Partition the string into three parts using the given separator.

 
 >>> string.rsplit(sep=None, maxsplit=-1) -->  Return a list of the words in the string, using sep as
                                                 the delimiter string.
    
 
 >>> string.rstrip(chars=None) -->  Return a copy of the string with trailing whitespace removed.

 
 >>> string.split(sep=None, maxsplit=-1) -->  Return a list of the words in the string, using sep as 
                                                the delimiter string.
        
 
 >>> string.splitlines(keepends=False) -->  Return a list of the lines in the string, breaking at line boundaries.

 
 >>> string.strip(chars=None) -->  Return a copy of the string with leading and trailing whitespace removed.
    
 
 >>> string.swapcase() -->  Convert uppercase characters to lowercase and lowercase characters to uppercase.
   
________________________________________________________________________________________________________________________ 
    
    
 >>> string.translate(table)
      => This replaces each character in the string using the given translation table.
    

 >>> string.title() --> This return a version of the string where each word is titlecased (Python, Language etc.)

 
 >>> string.upper() -->  This return a copy of the string with letters in uppercase.
    
 
 >>> string.zfill(width) -->  This fills 0(zeroes) on left of strings. Width specifies, how wide
                                you want to fill zeroes. 
    
      => width should be greater than length of strings.
                              
      => NOTE - if width <= len(string), then no zeroes will be filled.

# %% [markdown]
# <img src="images/string-constants1.png">

# %% [markdown]
# <img src="images/string-methods1.png">

# %% [markdown]
# <img src="images/string-methods4.png">

# %% [markdown]
# [ For Python Documentation Over Strings, CLICK HERE ](https://docs.python.org/3/tutorial/introduction.html#strings)
